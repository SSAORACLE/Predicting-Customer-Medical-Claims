# %%
from Medical_claims_module import *

# %%
df = pd.read_csv(r'claims_data.csv')

# %%
df.head()
# Out:
#    age     sex     bmi  steps  children smoker     region insurance_claim  \
# 0   19  female  27.900   3009         0    yes  southwest             yes
# 1   18    male  33.770   3008         1     no  southeast             yes
# 2   28    male  33.000   3009         3     no  southeast              no
# 3   33    male  22.705  10009         0     no  northwest              no
# 4   32    male  28.880   8010         0     no  northwest             yes
#
#    claim_amount
# 0    16884.9240
# 1     1725.5523
# 2        0.0000
# 3        0.0000
# 4     3866.8552

# %%
model = model('model','Claim_scaler')

# %%
model.load_and_clean_data('claims_data.csv')
# Out:
# C:\Users\NKAZIMULO BUTHELEZI\Videos\Integration\Medical_claims_module.py:31: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   X_scaled = pd.DataFrame(self.scaler.transform(X[self.columns]), columns=self.columns)

# %%
model.predicted_outputs()
# Out:
#       age     bmi  steps  children  sex_female  sex_male  smoker_no  \
# 0      19  27.900   3009         0           1         0          0
# 1      18  33.770   3008         1           0         1          1
# 2      28  33.000   3009         3           0         1          1
# 3      33  22.705  10009         0           0         1          1
# 4      32  28.880   8010         0           0         1          1
# 5      31  25.740   8005         0           1         0          1
# 6      46  33.440   3002         1           1         0          1
# 7      37  27.740   8007         3           1         0          1
# 8      37  29.830   8002         2           0         1          1
# 9      60  25.840   5008         0           1         0          1
# 10     25  26.220   8006         0           0         1          1
# 11     62  26.290   5004         0           1         0          0
# 12     23  34.400   3008         0           0         1          1
# ...
